# %%
from main import Game

# %%
the_game = Game(3823)

# %%
the_game.get_cards()

# %%
the_game.prepare()
# Out:
# Please input your name:
# Please input your email:
# Welcome Richard, have fun!
# Please input your name:
# Please input your email:
# Welcome Julia, have fun!
# Please input your name:
# Please input your email:
# Welcome Eva, have fun!
# Please input your name:
# Please input your email:
# Welcome Yuri, have fun!

# %%
the_game.on_going()
# Out:
# Current onboard cards are:
# ************************************************
# ************************************************
#
# It is Yuri's turn.
#
# You currently have:
# Heart 2, 4, 5, 7.
# Diamond 4, 10, 13.
# Spade 3, 6, 7, 10.
# Club 4, 9.
#
# You have suppressed:
#
# You current available cards are:
# Heart 7 is available, use card code 23 if you want to use.
# Spade 7 is available, use card code 36 if you want to use.
#
# Please input the card code you want to issue: 36
#
# Current onboard cards are:
# ************************************************
# Spade 7.
# ************************************************
#
# It is Richard's turn.
#
# You currently have:
# Heart 8, 9, 13.
# Diamond 6, 7, 9, 12.
# Spade 2, 9.
# Club 2, 5, 8, 10.
#
# You have suppressed:
#
# You current available cards are:
# Diamond 7 is available, use card code 12 if you want to use.
#
# Please input the card code you want to issue: 12
#
# Current onboard cards are:
# ...
